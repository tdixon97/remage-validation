# %%
import utils

# %%
# test setting up the folder

# %%
utils.setup_folder("out/test/")

# %%
gen = utils.get_generator(name="th228")

# %%
reps = utils.get_replacements(
    gen,
    cluster_dist=1,
    sensitive_cut=0.1,
    step_limit=0.2,
    register_lar=False,
    source="germanium",
)

# %%
reps

# %%
utils.make_macro("config/macro.mac", reps, "test.mac")
